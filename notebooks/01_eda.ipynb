# %% [markdown]
# # Retail Sales Analytics EDA Notebook
#
# This notebook is a reproducible analysis companion for the portfolio project.

# %%
from pathlib import Path
import pandas as pd
DATA = Path('../data/processed')
csvs = sorted(DATA.glob('*.csv'))
[(p.name, pd.read_csv(p).shape) for p in csvs]

# %% [markdown]
# ## Analysis Plan
# - Validate row counts, nulls, and duplicate records.
# - Profile KPI trends and segment performance.
# - Translate findings into business recommendations.
